# %% [markdown]
# * [ . ] create api key in development workspace
# * [ . ] test with postman
# * [ . ] csv upload into pandas
#
#
# functions:
# * [ . ] bulk
# * [ . ] diff
# * [ . ] bulk delete
# * [ . ] search and update
#
# Workspace token
# Editor access
# - edit configurations
# - connect or disconnect transformations, trancking plans, models, and audiences
#
# Transfomrations edit access turned off

# %%
# %pip install dotenv

# %%
import dotenv
dotenv.load_dotenv()

import os
import requests

RS_API_KEY = os.getenv("RUDDERSTACK_API_KEY")
RS_API_URL = "https://api.rudderstack.com/v1"

headers = {
    "Authorization": f"Bearer {RS_API_KEY}",
    "Content-Type": "application/json",
}

response = requests.get(f"{RS_API_URL}/sources", headers=headers)
print(response.json())
