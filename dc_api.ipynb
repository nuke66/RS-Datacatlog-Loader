# %% [markdown]
# * [ . ] create api key in development workspace
# * [ . ] test with postman
# * [ . ] csv upload into pandas
#
#
# functions:
# * [ . ] bulk
# * [ . ] diff
# * [ . ] bulk delete
# * [ . ] search and update
# * [ . ] remove events from tracking plan
#
# Workspace token
# Editor access
# - edit configurations
# - connect or disconnect transformations, trancking plans, models, and audiences
#
# Transfomrations edit access turned off
#
#
# development workspace id: 2xNiB5LbopGv3ktZWbpQXyWEaCg
#
#
# trail production workspace id: 2rlLlF1YD5t4adRZGQbkvbHsFdw

# %%
# %pip install dotenv
# Out:
# Requirement already satisfied: dotenv in d:\dev\notebooks\geocoding\.conda\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in d:\dev\notebooks\geocoding\.conda\lib\site-packages (from dotenv) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import dotenv
import json
dotenv.load_dotenv()

import os
import requests
import pandas as pd

RS_API_KEY = os.getenv("RUDDERSTACK_API_KEY")
RS_API_URL = "https://api.rudderstack.com"

headers = {
    "Authorization": f"Bearer {RS_API_KEY}",
    "Content-Type": "application/json",
}

# %% [markdown]
# ---
# ## Events

# %%
# create event
body = {
  "name": "SXH test event 11 ",
  "description": "Created with API",
  "eventType": "track",
  "categoryId": None
}

response = requests.post(f"{RS_API_URL}/v2/catalog/events", json=body, headers=headers )
print(response.json())

# %%
# get events

response = requests.get(f"{RS_API_URL}/v2/catalog/events?page=1&orderBy=name:asc", headers=headers )

#print(response.json())
print(json.dumps(response.json()["data"], indent=4, sort_keys=True))
# Out:
# [
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:58.533Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks \u2018back\u2019 as they progress through the AO form. This will fire alongside ao_screen_nav",
#         "eventType": "track",
#         "id": "ev_2z2Dd6KXUYxA0xGXDie5dcJm9wx",
#         "name": "ao_back",
#         "updatedAt": "2025-06-26T06:45:58.533Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:59.924Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be fired when the confirmation screen is loaded, following an application being submitted. It should NOT fire if the user receives an error screen.Note: The event should trigger only the first time this pages is loaded. If the page is refreshed at any point it should not trigger another completion, although it can fire another ao_screen_loaded event.",
#         "eventType": "track",
#         "id": "ev_2z2DdIlrDusiEuHiGDuMUoSuyTQ",
#         "name": "ao_complete",
#         "updatedAt": "2025-06-26T06:45:59.924Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:57.504Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks \u2018next\u2019 as they progress through the Apply Online form. It should also be triggered if a user navigates back and then updates their selection. This event will fire alongside ao_screen_nav event.",
#         "eventType": "track",
#         "id": "ev_2z2Dd2jmww0g4aSPAiRYvp3mLSi",
#         "name": "ao_next",
#         "updatedAt": "2025-06-26T06:45:57.504Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:56.664Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire each time a new screen is loaded as a user progresses through the Apply Online tool.",
#         "eventType": "track",
#         "id": "ev_2z2DcsfHefgY09t3UzoCMfMAyXO",
#         "name": "ao_screen_loaded",
#         "updatedAt": "2025-06-26T06:45:56.664Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:57.121Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire each time a user interacts with the \u2018Navigation\u2019 buttons on their active screen. Depending on which screen they see this could be next, back, continue to, submit, edit etc.In most cases this should fire alongside ao_next and ao_back events",
#         "eventType": "track",
#         "id": "ev_2z2Dd2RVEQGeP1cr3UVCe9bLXfN",
#         "name": "ao_screen_nav",
#         "updatedAt": "2025-06-26T06:45:57.121Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:27.601Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks any of the \u2018Start now\u2019 buttons on the \u2018Request an assessment online\u2019 page.",
#         "eventType": "track",
#         "id": "ev_2z2DZFaeJeNsvjbNqliSpHfSGTo",
#         "name": "ao_start",
#         "updatedAt": "2025-06-26T06:45:27.601Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:18.297Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user clicks \u2018Add provider\u2019 after selecting their preferred ACH outlet from the shortlist.",
#         "eventType": "track",
#         "id": "ev_2z2DfguSF9r16JPVK5NuqzSVBOJ",
#         "name": "bp_add_ach_complete",
#         "updatedAt": "2025-06-26T06:46:18.297Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:17.731Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user clicks to add an ACH outlet to their budget planner.",
#         "eventType": "track",
#         "id": "ev_2z2DfSjlPh9ETYmb6azfTVeXJvZ",
#         "name": "bp_add_ach_start",
#         "updatedAt": "2025-06-26T06:46:17.731Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:14.059Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be fired whenever a user presses \u2018back\u2019 when adding a provider/service to their budget planner.",
#         "eventType": "track",
#         "id": "ev_2z2DfASnNYZxLdogNDPX9s0vCzk",
#         "name": "bp_add_service_back",
#         "updatedAt": "2025-06-26T06:46:14.059Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:14.533Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be fired when a user submits their service selection in the budget planner.",
#         "eventType": "track",
#         "id": "ev_2z2Df6JrGFCFCOyofbeJweVE6AI",
#         "name": "bp_add_service_complete",
#         "updatedAt": "2025-06-26T06:46:14.533Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:12.919Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be fired when a user progresses through questions in the \u2018Add service\u2019 flow. This will only apply to the \u2018Search for a service\u2019 interaction.",
#         "eventType": "track",
#         "id": "ev_2z2DeqOdVqe7wTKWomnLigumNIi",
#         "name": "bp_add_service_next",
#         "updatedAt": "2025-06-26T06:46:12.919Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:12.325Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered whenever a user adds a a provider or a service to their budget planner.This also fires when a user selects \u2018edit\u2019 - this will trigger flow_type = update.",
#         "eventType": "track",
#         "id": "ev_2z2DernUDWSrX00rFb3G6pWQuGn",
#         "name": "bp_add_service_start",
#         "updatedAt": "2025-06-26T06:46:12.325Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:20.485Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be fired when a user has any of the following interactions with a component on the budget planner:clicksexpand/collapsecheck/uncheckopen/close",
#         "eventType": "track",
#         "id": "ev_2z2DfrCPiw8pEQRYq1GAO6xmZCQ",
#         "name": "bp_detail_interaction",
#         "updatedAt": "2025-06-26T06:46:20.485Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:17.203Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user adds/edits a service that triggers a warning that they over their allocated budget.",
#         "eventType": "track",
#         "id": "ev_2z2DfW1sCbjqQObJW5ZQgoBdjxf",
#         "name": "bp_over_budget_attempt",
#         "updatedAt": "2025-06-26T06:46:17.203Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:16.588Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user removes a service from their planner (after opening the Edit window).",
#         "eventType": "track",
#         "id": "ev_2z2DfPF9TP6ykTVsRkd7J6TzZAq",
#         "name": "bp_remove_service",
#         "updatedAt": "2025-06-26T06:46:16.588Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:19.237Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user clears all of their services, or resets their ACH provider. It should not be fired when they open/close the \u2018Clear all services\u2019 modal (this will be covered by detail interactions below).",
#         "eventType": "track",
#         "id": "ev_2z2DfiWVou5TbxEEddEumoANStW",
#         "name": "bp_reset",
#         "updatedAt": "2025-06-26T06:46:19.237Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:18.760Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire whenever a user selects a new room type from the dropdown.",
#         "eventType": "track",
#         "id": "ev_2z2DfabSdiPdsQBokKoOMd0cqSl",
#         "name": "bp_update_room_option",
#         "updatedAt": "2025-06-26T06:46:18.760Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:19.697Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered each time the \u2018budget planner\u2019 is viewed - regardless of whether services/providers have or have not been added. Each time a user adds a service, or changes the front end display of the page (ie. Toggling QTR vs Month, changing room type) the event should fire again.",
#         "eventType": "track",
#         "id": "ev_2z2Dfok2W9gYn6bwaynVhjdtO41",
#         "name": "bp_view",
#         "updatedAt": "2025-06-26T06:46:19.697Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:56.247Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user Opens/Closes the Edit Compare drawer. It also fires if the user toggles between the active care type within the drawer.For SAH, this will also apply to opening/closing the change/select services to compare drawers - and toggling between care type within this drawer.This should also fire on the SAH drawers (select a care type + select services to compare), for situations where we do not already know the care type + user services.",
#         "eventType": "track",
#         "id": "ev_2z2DctLWlsZZ9jqUYu4ZlfyvJ4X",
#         "name": "compare_edit",
#         "updatedAt": "2025-06-26T06:45:56.247Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:54.661Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user views the compare page.",
#         "eventType": "track",
#         "id": "ev_2z2DceLsO2RgJ6lNbZhkG9QPutb",
#         "name": "compare_view",
#         "updatedAt": "2025-06-26T06:45:54.661Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:17.962Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "When a user has any of the following interactions with a component on the website:  click, expand, collapse, check, uncheck, open, close",
#         "eventType": "track",
#         "id": "ev_2z2DXyOLeWGrG4IkMx8bx5ln3pS",
#         "name": "component_interaction",
#         "updatedAt": "2025-06-26T06:45:17.962Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:31.365Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event tracks the submissions of completed end-of-life forms. It should trigger when the user clicks on 'Submit'.",
#         "eventType": "track",
#         "id": "ev_2z2DZi1cQC3YA1UkrpDNYfGNEaN",
#         "name": "eol_complete",
#         "updatedAt": "2025-06-26T06:45:31.365Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:30.899Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event tracks the progression of user through the end-of-life form. It should trigger when the user uploads the mandatory end-of-life documentation and clicks on the 'Next' button.",
#         "eventType": "track",
#         "id": "ev_2z2DZbzdHfhTEoYuhzlKbaW6wg5",
#         "name": "eol_next",
#         "updatedAt": "2025-06-26T06:45:30.899Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:30.029Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should trigger only when the user has selected \u2018End of Life' and clicked on 'Access form' in the 'Reason for Referral' section.",
#         "eventType": "track",
#         "id": "ev_2z2DZc7MTeFZzNrkey74SSuhwNr",
#         "name": "eol_start",
#         "updatedAt": "2025-06-26T06:45:30.029Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:54.185Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event is used to track all of the other micro-interactions a user can complete across FAP search pages like: clear, save search sort, open/close filters, add/remove filters, pagination.",
#         "eventType": "track",
#         "id": "ev_2z2Dca6D3XRT28sor49B8q3dibL",
#         "name": "fap_interaction",
#         "updatedAt": "2025-06-26T06:45:54.185Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:49.421Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user searches for an outlet using one of the following search options: Personalised search (prefilled personalised values, or from fap wayfinder), Normal search  (input values - includes applying/updating filtering), Quick search (recent or saved search), Location search (Help Explorer, Provider pages)",
#         "eventType": "track",
#         "id": "ev_2z2DbyJ6yKQEfmxbI87r5DbA8ol",
#         "name": "fap_outlet_search",
#         "updatedAt": "2025-06-26T06:45:49.421Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:53.000Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user interacts with the Provider search feature. Please note, clicking an option from the dropdown should also trigger a \u2018provider_interaction\u2019 event.",
#         "eventType": "track",
#         "id": "ev_2z2DcXINRtpQBYyjemg6DRP2jZT",
#         "name": "fap_provider_search",
#         "updatedAt": "2025-06-26T06:45:53.000Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:44.268Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user clicks \u2018next\u2019 as they progress through the wayfinder tool. It should also be triggered if a user navigates back and then updates their selection.",
#         "eventType": "track",
#         "id": "ev_2z2DbQ1TWXnOLgBV3EXueLzFcoW",
#         "name": "fap_wayfinder_next",
#         "updatedAt": "2025-06-26T06:45:44.268Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:44.675Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user presses \u2018Skip\u2019 whilst using the FAP Wayfinder tool.",
#         "eventType": "track",
#         "id": "ev_2z2DbKZKRCy9FFWNHZP0WOFBKxI",
#         "name": "fap_wayfinder_skip",
#         "updatedAt": "2025-06-26T06:45:44.675Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:43.790Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user opens the FAP Wayfinder \u2018Drawer\u2019 by clicking \u2018Find a provider\u2019 or \u2018Clear and start a new search\u2019.",
#         "eventType": "track",
#         "id": "ev_2z2DbBdxnNSBbapheNlW7pGE4hZ",
#         "name": "fap_wayfinder_start",
#         "updatedAt": "2025-06-26T06:45:43.790Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:42.815Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "There are numerous interactions a user can have within HE, including clicking on story, service, aid and specialisation components on overview or story pages. This event also fires for generic interactions like clicking load more or see all.",
#         "eventType": "track",
#         "id": "ev_2z2Db4jEm7z0uNT4dK1EXRGLC0G",
#         "name": "he_interaction",
#         "updatedAt": "2025-06-26T06:45:42.815Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:42.203Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event tracks the various interactions users can have with personalisation features in the HE section of the website. These interactions include: start personalisation, complete personalisation, edit personalisation",
#         "eventType": "track",
#         "id": "ev_2z2Db5HyYlVRZGtUDgyvYnYPI5Q",
#         "name": "he_personalise",
#         "updatedAt": "2025-06-26T06:45:42.203Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:41.580Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user view the HE landing page (any variation), or a Story page. The purpose of this event is to determine which variants of each page people are more engaged with.",
#         "eventType": "track",
#         "id": "ev_2z2Daw39zl02iVvqXoq8LxaYeTU",
#         "name": "he_view",
#         "updatedAt": "2025-06-26T06:45:41.580Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:28.314Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event triggers when user navigates back to the previous section",
#         "eventType": "track",
#         "id": "ev_2z2DZOq9jVRc42Rj4o7atWArXCg",
#         "name": "mar_back",
#         "updatedAt": "2025-06-26T06:45:28.314Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:29.423Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when the MAR confirmation screen is loaded.",
#         "eventType": "track",
#         "id": "ev_2z2DZRx6AUSzToy9GQTy3fZrk8i",
#         "name": "mar_complete",
#         "updatedAt": "2025-06-26T06:45:29.423Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:28.800Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event triggers when the user interacts with the menu stepper",
#         "eventType": "track",
#         "id": "ev_2z2DZMALm0hd72KKao50j3g8HqB",
#         "name": "mar_menu_stepper",
#         "updatedAt": "2025-06-26T06:45:28.800Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:25.599Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event is triggered when the user completes a section of Make a referral.",
#         "eventType": "track",
#         "id": "ev_2z2DZ2LmwgR30Ce9pqD6vtZHvOy",
#         "name": "mar_next",
#         "updatedAt": "2025-06-26T06:45:25.599Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:45:24.842Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should trigger when a user selects a role and clicks on 'Start referral'.",
#         "eventType": "track",
#         "id": "ev_2z2DYqj9441YPygzEueWpyEHjnp",
#         "name": "mar_start",
#         "updatedAt": "2025-06-26T06:45:24.842Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:03.153Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks \u2018back\u2019 as they progress through the question set (relevant to their flow). This applies to all flows (including situation, interests and assessment).",
#         "eventType": "track",
#         "id": "ev_2z2DdonaS8VrcOGJ8v1lGCC5trL",
#         "name": "mg_back",
#         "updatedAt": "2025-06-26T06:46:03.153Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:05.348Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user completes their My Guide flow. Onboarding/Checklist - clicking \u2018Go to my guide' at end of question set (or being redirected after this screen)Client Checklist - clicking \u2018Delete and close\u2019 on Summary pageSituation/Interests - clicking \u2018Done\u2019 on Summary pageAssessment - clicking \u2018Add assessment outcome\u2019 or \u2018Done\u2019 on Summary page (depending on which flow the user is in)",
#         "eventType": "track",
#         "id": "ev_2z2De24XwvCyLHPea2w3ifrBuKB",
#         "name": "mg_complete",
#         "updatedAt": "2025-06-26T06:46:05.348Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:07.912Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user deletes their guide (pressing \u2018Delete selected\u2019). It should not be fired when they open/close the modal (this will be covered by detail interactions below).",
#         "eventType": "track",
#         "id": "ev_2z2DeDXYIXBNEdd9NYTjTQ4i9tI",
#         "name": "mg_delete",
#         "updatedAt": "2025-06-26T06:46:07.912Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:08.341Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event will fire when a user engages with any of the components located across the various My Guide pages. These interactions include: clicks, expand/collapse, check/uncheck, open/close",
#         "eventType": "track",
#         "id": "ev_2z2DeNbmOXa82AXc2vWZ1t39bj3",
#         "name": "mg_detail_interaction",
#         "updatedAt": "2025-06-26T06:46:08.341Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:02.700Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks \u2018next\u2019 as they progress through the question set (relevant to their flow). It should also be triggered if a user navigates back and then updates their selection.This does not apply to updating situation or interests, but it does apply when updating assessment outcomes.",
#         "eventType": "track",
#         "id": "ev_2z2Ddc4DRLehV95BUTEjUXkIgHI",
#         "name": "mg_next",
#         "updatedAt": "2025-06-26T06:46:02.700Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:06.506Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user opens their My Guide. It should only fire once per session. This could be triggered by:Clicking \u2018My Guide\u2019 in the header navClicking on any of the \u2018My Guide\u2019 popups that may appear across the website",
#         "eventType": "track",
#         "id": "ev_2z2De5gY9l5ecmJwFuFTAFHvR1W",
#         "name": "mg_open",
#         "updatedAt": "2025-06-26T06:46:06.506Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:02.207Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered in a number of places:when a user clicks \u2018Create your own guide\u2019 on the My Guide landing pagewhen a user clicks \u2018Create a checklist\u2019 on the \u2018My checklist\u2019 page (for themselves or as a professional, for their patient)when a user clicks \u2018Add my assessment result\u2019 on the \u2018My situation and needs\u2019 pagewhen a user clicks \u2018Update\u2019 on the \u2018My situation and needs\u2019 page (applies to all sections - Assessment, Situation and Interests)",
#         "eventType": "track",
#         "id": "ev_2z2Ddf2kDNyr00hqZcUdt9xAT5f",
#         "name": "mg_start",
#         "updatedAt": "2025-06-26T06:46:02.207Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:04.967Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This interaction should fire when a user clicks \u2018update\u2019 whilst within the section drawer.For conditional flows like Assessment (and maybe client checklist tbd.) this interaction won\u2019t apply - instead mg_next will fire as a user proceeds through the question flow, and the flow_type parameter will be updated from \u201cAdd data\u201d to \u201cUpdate data\u201d.",
#         "eventType": "track",
#         "id": "ev_2z2DdrXiyPFD85NLoahbNaWOfim",
#         "name": "mg_update_complete",
#         "updatedAt": "2025-06-26T06:46:04.967Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:04.426Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should fire when a user opens a section drawer, or navigates back to a previous question in their flow by pressing \u2018update\u2019 within the summary page.",
#         "eventType": "track",
#         "id": "ev_2z2Ddr33wOrjTmnCyZiRyalFI6B",
#         "name": "mg_update_start",
#         "updatedAt": "2025-06-26T06:46:04.426Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:06.976Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user views any page (section) of their My Guide.",
#         "eventType": "track",
#         "id": "ev_2z2De4tJB2nmWwMbmRNudvzEf1y",
#         "name": "mg_view",
#         "updatedAt": "2025-06-26T06:46:06.976Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:03.784Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered each time a user views a \u2018Summary\u2019 screen within the My Guide question flows:When a user initially opens Situation, Interests, or Assessment - after pressing \u2018Update\u2019 from within the My Situation pageAt the end of the Assessment flow, before a user submits their changesAt the end of the Client Checklist flow, before a Professional shares and deletes the guideAfter updating a section within the Situation or Interests flows",
#         "eventType": "track",
#         "id": "ev_2z2Ddm30TOY5TMnUAfZr10mcPys",
#         "name": "mg_view_summary",
#         "updatedAt": "2025-06-26T06:46:03.784Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "categoryId": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "createdAt": "2025-06-26T06:46:09.799Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "This event should be triggered when a user clicks \u2018back\u2019 as they progress through the question set (relevant to their flow).",
#         "eventType": "track",
#         "id": "ev_2z2DeWuQJxEXVXXwrphYXyXmoB1",
#         "name": "my_costs_back",
#         "updatedAt": "2025-06-26T06:46:09.799Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     }
# ]

# %%
# delete events
event_id = "ev_2xzHZ84lzRRb7Q2un3aH0BDEIjj"

response = requests.delete(f"{RS_API_URL}/v2/catalog/events/{event_id}", headers=headers )
#print(response.json())

if (response.status_code != 200):
    print(f"Error [{response.status_code}]: id:{event_id}  {response.json()['error']}")
# Out:
# Error [400]: id:ev_2xzHZ84lzRRb7Q2un3aH0BDEIjj  Event is connected to tracking plan test-tracking-plan. Please disconnect and try again.

# %% [markdown]
# ---
# ## Properties

# %%
# create property


body = {
  "name": "test-test-test2",
  "description": "where is this going",
  "type": "number"
}

response = requests.post(f"{RS_API_URL}/v2/catalog/properties", json=body, headers=headers )
print(response.json())
# Out:
# {'propConfig': {}, 'name': 'test-test-test2', 'description': 'where is this going', 'type': 'number', 'arrayItemTypes': '', 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg', 'definitionId': None, 'itemDefinitionId': None, 'createdBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY', 'id': 'prop_2yfZazh1DjH0hMDETmzJ2QZZrGL', 'createdAt': '2025-06-18T06:20:55.548Z', 'updatedAt': '2025-06-18T06:20:55.548Z'}

# %%
# List properties

response = requests.get(f"{RS_API_URL}/v2/catalog/properties?page=1&orderBy=name:asc", headers=headers )
print(json.dumps(response.json(), indent=4, sort_keys=True))
#print("*********************")

df_properties = pd.DataFrame(response.json()['data'])
if df_properties.empty:
    print("No properties found")
else:
    df_properties.index = df_properties['id']

df_properties

# %%
# List properties with pagination

import math
response = requests.get(f"{RS_API_URL}/v2/catalog/properties?page=1&orderBy=name:asc", headers=headers )
#print(json.dumps(response.json(), indent=4, sort_keys=True))

properties = []
if response.status_code == 200:
    properties = response.json()['data']
    
    # work out how many pages there are
    total_events = response.json()['total']
    page_size = response.json()['pageSize']
    total_pages = math.ceil(total_events / page_size)
    print(f"Total events: {total_events}")
    print(f"Page size: {page_size}")
    print(f"Total pages: {total_pages}")
    if (total_pages > 1):
        for page in range(2, total_pages + 1):
            response = requests.get(f"{RS_API_URL}/v2/catalog/properties?page={page}&orderBy=name:asc", headers=headers )
            
            if response.status_code == 200:
                properties.extend(response.json()['data'])
else:
    print(f"Error: [{response.status_code}] {response.json()['error']}")
    


df_properties = pd.DataFrame(properties)
if df_properties.empty:
    print("No properties found")
else:
    df_properties.index = df_properties['id']

print(df_properties)
# Out:
# Total events: 86
# Page size: 50
# Total pages: 2
#                                  propConfig                                id  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac         {}  prop_2yz6GpoNsVXpbchXrSwEmonU4ac
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7         {}  prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK         {}  prop_2yz69fZXEZ625t1ldGWRUuRVqqK
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx         {}  prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I         {}  prop_2yz6BIwJEW7lO3UEW1c4Alald0I
# ...                                     ...                               ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46         {}  prop_2yz6DDykf8MwjkuPFjf1dQlaq46
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu         {}  prop_2yz6A1I5aJDiBt5HcTtldysyCXu
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy         {}  prop_2yz6ENtVczez3SCCJPK3j4hlbOy
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4         {}  prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE         {}  prop_2yz6ESB5i75Vyi9y1G4nK1YMppE
#
#                                                  name  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  ach_budget_estimate
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7        ach_room_cost
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK      active_question
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx        active_screen
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I                  age
# ...                                               ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46            user_data
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu            user_type
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy                 uuid
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4           view_count
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE          visit_count
#
#                                                                         description  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  For ACH, an object containing the daily fee es...
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7  An object containing the outlet name + room ty...
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK  Displays the text associated with the question...
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx  The title associated with the current screen b...
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I  This parameter shows the age of the person usi...
# ...                                                                             ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46  A structured object containing the user data b...
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu  This parameter tracks weather the user is new ...
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy  The unique ID associated with the guide (based...
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  An integer value that counts how many times a ...
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  The number of times a user has visited their g...
#
#                                      type arrayItemTypes  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac   string
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7   string
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK   string
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx   string
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I   string
# ...                                   ...            ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46   string
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu   string
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy   string
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  integer
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  integer
#
#                                                   workspaceId definitionId  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# ...                                                       ...          ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  2xNiB5LbopGv3ktZWbpQXyWEaCg         None
#
#                                  itemDefinitionId  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac             None
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7             None
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK             None
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx             None
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I             None
# ...                                           ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46             None
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu             None
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy             None
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4             None
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE             None
#
#                                                     createdBy updatedBy  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# ...                                                       ...       ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  2yfWcUocZJfd7iQNO0ct6IlX3WY      None
#
#                                                  createdAt  \
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  2025-06-25T04:16:01.370Z
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7  2025-06-25T04:16:00.174Z
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK  2025-06-25T04:15:04.454Z
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx  2025-06-25T04:15:29.985Z
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I  2025-06-25T04:15:17.520Z
# ...                                                    ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46  2025-06-25T04:15:32.406Z
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu  2025-06-25T04:15:07.378Z
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy  2025-06-25T04:15:41.581Z
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  2025-06-25T04:15:21.512Z
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  2025-06-25T04:15:42.659Z
#
#                                                  updatedAt
# id
# prop_2yz6GpoNsVXpbchXrSwEmonU4ac  2025-06-25T04:16:01.370Z
# prop_2yz6GfRPsgmSqSiqhM6YhPGBZf7  2025-06-25T04:16:00.174Z
# prop_2yz69fZXEZ625t1ldGWRUuRVqqK  2025-06-25T04:15:04.454Z
# prop_2yz6Cp0ltOB8uctz1Qa3jkMA7vx  2025-06-25T04:15:29.985Z
# prop_2yz6BIwJEW7lO3UEW1c4Alald0I  2025-06-25T04:15:17.520Z
# ...                                                    ...
# prop_2yz6DDykf8MwjkuPFjf1dQlaq46  2025-06-25T04:15:32.406Z
# prop_2yz6A1I5aJDiBt5HcTtldysyCXu  2025-06-25T04:15:07.378Z
# prop_2yz6ENtVczez3SCCJPK3j4hlbOy  2025-06-25T04:15:41.581Z
# prop_2yz6Bpg2x3ARdQr84RDy2Oe0YT4  2025-06-25T04:15:21.512Z
# prop_2yz6ESB5i75Vyi9y1G4nK1YMppE  2025-06-25T04:15:42.659Z
#
# [86 rows x 13 columns]

# %%
# Delete properites

if df_properties.shape[0] > 0:
    property_ids = df_properties['id'].tolist()
    print(property_ids)

    for property_id in property_ids:
        response = requests.delete(f"{RS_API_URL}/v2/catalog/properties/{property_id}", headers=headers)
        print(response.json())
else:
    print("No properties to delete")

# %% [markdown]
# ---
# # Tracking plan

# %%
# create tracking plan

body = {
    "name": "test-tracking-plan2",
    "display_name": "test",
    "description": "testing api"
}
response = requests.post(f"{RS_API_URL}/v2/catalog/tracking-plans", json=body, headers=headers )


print(response.json())
# Out:
# {'id': 'tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI', 'name': 'test-tracking-plan2', 'description': 'testing api', 'version': 1, 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg', 'creationType': 'Data catalog API', 'createdAt': '2025-06-23T05:47:38.918Z', 'updatedAt': '2025-06-23T05:47:38.918Z'}

# %%
# get all tracking plans

response = requests.get(f"{RS_API_URL}/v2/catalog/tracking-plans", headers=headers )
print(response.json())

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {'trackingPlans': [{'id': 'tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI', 'name': 'test-tracking-plan2', 'description': 'testing api', 'version': 1, 'createdAt': '2025-06-23T05:47:38.918Z', 'updatedAt': '2025-06-23T05:47:38.918Z', 'creationType': 'Data catalog API', 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg'}, {'id': 'tp_2yfZvfHPjGdlzuTi9hr7dKubpY8', 'name': 'test-tracking-plan', 'description': 'testing api', 'version': 3, 'createdAt': '2025-06-18T06:23:39.371Z', 'updatedAt': '2025-06-20T00:57:53.952Z', 'creationType': 'Data catalog API', 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg'}]}
# {
#     "trackingPlans": [
#         {
#             "createdAt": "2025-06-23T05:47:38.918Z",
#             "creationType": "Data catalog API",
#             "description": "testing api",
#             "id": "tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI",
#             "name": "test-tracking-plan2",
#             "updatedAt": "2025-06-23T05:47:38.918Z",
#             "version": 1,
#             "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#         },
#         {
#             "createdAt": "2025-06-18T06:23:39.371Z",
#             "creationType": "Data catalog API",
#             "description": "testing api",
#             "id": "tp_2yfZvfHPjGdlzuTi9hr7dKubpY8",
#             "name": "test-tracking-plan",
#             "updatedAt": "2025-06-20T00:57:53.952Z",
#             "version": 3,
#             "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#         }
#     ]
# }

# %%
# get tracking plan by id

tracking_plan_id = "tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI"

response = requests.get(f"{RS_API_URL}/v2/catalog/tracking-plans/{tracking_plan_id}", headers=headers )
#print(response.json())
print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# {
#     "createdAt": "2025-06-23T05:47:38.918Z",
#     "creationType": "Data catalog API",
#     "description": "testing api",
#     "id": "tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI",
#     "name": "test-tracking-plan2",
#     "updatedAt": "2025-06-23T05:47:38.918Z",
#     "version": 1,
#     "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
# }

# %%
# Delete tracking plan
tracking_plan_id = "tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI"

response = requests.delete(f"{RS_API_URL}/v2/catalog/tracking-plans/{tracking_plan_id}", headers=headers )
print(response.json())

# %% [markdown]
# ---
# # Tracking plan events

# %%
# create tracking plan
tracking_plan_name = "MAC website tracking"
tracking_plan_id = None

body = {
    "name": tracking_plan_name,
    "description": "Tracking plan for MAC website"
}

response = requests.post(f"{RS_API_URL}/v2/catalog/tracking-plans", headers=headers, json=body )
if (response.status_code == 200):
    tracking_plan_id = response.json()["id"]
    print(f"Tracking plan created successfully {tracking_plan_id}")
elif (response.status_code == 400):
    print(f"Failed to create tracking plan {response.json()}")
    print("Searching for existing tracking plan...",end="")
    # See if tracking plan already exists
    response = requests.get(f"{RS_API_URL}/v2/catalog/tracking-plans", headers=headers )
    if response.status_code == 200:
        tracking_plans = response.json()["trackingPlans"]
        if (len(tracking_plans) > 0):
            for tracking_plan in tracking_plans:
                if (tracking_plan["name"] == tracking_plan_name):
                    tracking_plan_id = tracking_plan["id"]
                    print(f"found plan {tracking_plan_id}")
                    break
        else:
            print(f"Error: No plan found ({tracking_plan_name})")
    else:
        print(f"Error: Request failed to get tracking plans {response.status_code}")       
else:
    print(f"Erorr - Failed to create tracking plan {response.status_code}")
# Out:
# Failed to create tracking plan {'error': 'Tracking plan with name MAC website tracking already exists'}
# Searching for existing tracking plan...found plan tp_2yz4ndOWgXBzuSKJJc68UgcxBmA
# tp_2yz4ndOWgXBzuSKJJc68UgcxBmA

# %%
# list tracking plans

tracking_plan_name = "MAC website tracking"
tracking_plan_id = None 

response = requests.get(f"{RS_API_URL}/v2/catalog/tracking-plans", headers=headers )
print(response)

if response.status_code == 200:
    tracking_plans = response.json()["trackingPlans"]
    print(tracking_plans)
    if (len(tracking_plans) > 0):
        for tracking_plan in tracking_plans:
            if (tracking_plan["name"] == tracking_plan_id):
                print(json.dumps(tracking_plan, indent=4, sort_keys=True))
                break
    else:
        print(f"Error: No tracking plans found ({tracking_plan_name})")       

print(json.dumps(response.json(), indent=4, sort_keys=True))
# Out:
# <Response [200]>
# [{'id': 'tp_2z2DiBjWPksES6CSM3fXNtubSZj', 'name': 'MAC website tracking', 'description': 'Tracking plan for MAC website', 'version': 82, 'createdAt': '2025-06-26T06:46:38.682Z', 'updatedAt': '2025-06-26T06:49:31.850Z', 'creationType': 'Data catalog API', 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg'}]
# {
#     "trackingPlans": [
#         {
#             "createdAt": "2025-06-26T06:46:38.682Z",
#             "creationType": "Data catalog API",
#             "description": "Tracking plan for MAC website",
#             "id": "tp_2z2DiBjWPksES6CSM3fXNtubSZj",
#             "name": "MAC website tracking",
#             "updatedAt": "2025-06-26T06:49:31.850Z",
#             "version": 82,
#             "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#         }
#     ]
# }

# %%
# List all events in a tracking plan

tracking_plan_id = 'tp_2z1HuzFypQ9MkDg3G2qESEcSwH8'

response = requests.get(f"{RS_API_URL}/v2/catalog/tracking-plans/{tracking_plan_id}/events&page=2", headers=headers )
#print(json.dumps(response.json()["data"], indent=4, sort_keys=True))

df_tracking_events = pd.DataFrame(response.json()["data"])

df_event_id = df_tracking_events[["id", "name"]].copy()
print(df_event_id)

# %%
# Upsert events with identifiers
# https://www.rudderstack.com/docs/api/data-catalog-api/tracking-plans/#upsert-event-with-identifiers

tracking_plan_id = "tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI"

body = {
    "id": "ev_2xzHzNZ6wGZO1cu1R0XHzuUQf1Q",
    "properties": [
        {
            "id": "prop_2yfWkC8q6rYc1UWCIm1KiFCsdHc",
            "required": False,
            "additionalProperties": False,
            "metadata": {},
            "properties": []
        }
    ]
}


response = requests.put(f"{RS_API_URL}/v2/catalog/tracking-plans/{tracking_plan_id}/events", headers=headers, json=body )
#print(response.json())

# %%
response.json()
# Out:
# {'id': 'tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI',
#  'name': 'test-tracking-plan2',
#  'version': 2,
#  'description': 'testing api',
#  'creationType': 'Data catalog API',
#  'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg',
#  'createdBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY',
#  'updatedBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY',
#  'dirty': False,
#  'createdAt': '2025-06-23T05:47:38.918Z',
#  'updatedAt': '2025-06-23T07:13:04.783Z',
#  'events': [{'trackingPlanId': 'tp_2ytdAHQ2rBY1K57E4AkWtIJ4kUI',
#    'eventId': 'ev_2xzHzNZ6wGZO1cu1R0XHzuUQf1Q',
#    'schemaId': 'sch_2ytnYVQvDnBNRzlqdziPMwteBIk',
#    'additionalProperties': True,
#    'identitySection': 'properties',
#    'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg',
#    'originSource': 'Data catalog',
#    'dirty': False,
#    'createdBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY',
#    'schema': {'rules': {'$schema': 'https://json-schema.org/draft/2019-09/schema',
#      'type': 'object',
#      'properties': {'properties': {'type': 'object',
#        'properties': {'test-test-test3': {'type': ['number']}},
#        'required': [],
#        'additionalProperties': True}}},
#     'id': 'sch_2ytnYVQvDnBNRzlqdziPMwteBIk',
#     'version': '1',
#     'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg',
#     'createdBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY',
#     'createdAt': '2025-06-23T07:13:04.783Z'},
#    'id': 'tpe_2ytnYZ2Ngzee7bYiyiQbBTIYh4G',
#    'createdAt': '2025-06-23T07:13:04.783Z',
#    'updatedAt': '2025-06-23T07:13:04.783Z',
#    'event': {'id': 'ev_2xzHzNZ6wGZO1cu1R0XHzuUQf1Q',
#     'name': 'SXH test event 11',
#     'description': 'Created with API',
#     'eventType': 'track',
#     'categoryId': None,
#     'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg',
#     'createdBy': '2xzHIrZMcaObaUyDPzkv63MeKBv',
#     'updatedBy': None,
#     'createdAt': '2025-06-03T07:04:03.865Z',
#     'updatedAt': '2025-06-03T07:04:03.865Z'}}]}

# %% [markdown]
# ---
# ## Categories

# %%
# Creat category

body = {
    "name": "MAC website",
    "description": "Event stream from MAC website"
}

response = requests.post(f"{RS_API_URL}/v2/catalog/categories", headers=headers, json=body )
print(response)
# Out:
# <Response [400]>

# %%
# List categories

response = requests.get(f"{RS_API_URL}/v2/catalog/categories", headers=headers )
#print(response.json())
print(json.dumps(response.json()["data"], indent=4, sort_keys=True))
# Out:
# [
#     {
#         "createdAt": "2024-03-07T12:33:51.482Z",
#         "createdBy": null,
#         "description": "",
#         "icon": "",
#         "id": "cat_2dMPAgS5hJ6ZyNoMTqJ0KrYQ3AM",
#         "name": "conversion",
#         "updatedAt": "2024-03-07T12:33:51.482Z",
#         "updatedBy": null,
#         "workspaceId": null
#     },
#     {
#         "createdAt": "2024-03-07T12:33:19.767Z",
#         "createdBy": null,
#         "description": "",
#         "icon": "",
#         "id": "cat_2dMP6d07v4BMacJlzHo2R3AdlC4",
#         "name": "general",
#         "updatedAt": "2024-03-07T12:33:19.767Z",
#         "updatedBy": null,
#         "workspaceId": null
#     },
#     {
#         "createdAt": "2025-06-24T22:13:44.905Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "Event stream from MAC website",
#         "icon": "star",
#         "id": "cat_2yyODDUFmTgMo3sOMSf7RSftHpc",
#         "name": "MAC website",
#         "updatedAt": "2025-06-24T22:13:44.905Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "createdAt": "2025-06-25T03:57:03.265Z",
#         "createdBy": "2yfWcUocZJfd7iQNO0ct6IlX3WY",
#         "description": "Tracking plan for MAC website",
#         "icon": "star",
#         "id": "cat_2yz3xsthxYJki6oY1zKATZxl2GE",
#         "name": "MAC website tracking",
#         "updatedAt": "2025-06-25T03:57:03.265Z",
#         "updatedBy": null,
#         "workspaceId": "2xNiB5LbopGv3ktZWbpQXyWEaCg"
#     },
#     {
#         "createdAt": "2024-03-07T12:33:42.400Z",
#         "createdBy": null,
#         "description": "",
#         "icon": "",
#         "id": "cat_2dMP9VzVpznfsrQtDSl56CARAnE",
#         "name": "marketing",
#         "updatedAt": "2024-03-07T12:33:42.400Z",
#         "updatedBy": null,
#         "workspaceId": null
#     },
#     {
#         "createdAt": "2024-03-07T12:33:31.670Z",
#         "createdBy": null,
#         "description": "",
#         "icon": "",
#         "id": "cat_2dMP84KwHtxT9kHAokPPh5TOQGS",
#         "name": "onboarding",
#         "updatedAt": "2024-03-07T12:33:31.670Z",
#         "updatedBy": null,
#         "workspaceId": null
#     }
# ]

# %%
for category in response.json()["data"]:
    if category["name"] == "MAC1 website":
        print(category["id"])
        break
# Out:
# cat_2yyP1Nh4iO6TF543WlpEul2iCVi

# %%
# delete category
categoryId = "cat_2yz3xsthxYJki6oY1zKATZxl2GE"
response = requests.delete(f"{RS_API_URL}/v2/catalog/categories/{categoryId}", headers=headers )
print(response)
print(response.json())
# Out:
# <Response [200]>
# {'name': 'MAC website tracking', 'description': 'Tracking plan for MAC website', 'icon': 'star', 'workspaceId': '2xNiB5LbopGv3ktZWbpQXyWEaCg', 'createdBy': '2yfWcUocZJfd7iQNO0ct6IlX3WY', 'updatedBy': None, 'createdAt': '2025-06-25T03:57:03.265Z', 'updatedAt': '2025-06-25T03:57:03.265Z'}
